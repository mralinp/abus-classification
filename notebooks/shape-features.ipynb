# %%
import cv2
import datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = datasets.Tumors()

# %%
x,m,y = dataset[0]

# %%
print(x.shape, m.shape)
# Out:
# (143, 177, 39) (143, 177, 39)

# %%
sample_slice = x[:,:,15]
sample_ground_truth = m[:,:,15]

# %%
for i in range(x.shape[2]):
    sample_slice = x[:,:,i]
    sample_ground_truth = m[:,:,i]
    plt.subplot(1,3,1)
    plt.imshow(sample_slice, cmap='gray')
    plt.subplot(1,3,2)
    plt.imshow(sample_ground_truth, cmap='gray')
    plt.subplot(1,3,3)
    plt.imshow(sample_slice-sample_slice*sample_ground_truth*0.4, cmap='gray')
    plt.savefig(f"./saved_images/{i}.png", bbox_inches='tight', transparent=True)
    plt.show()

# %%
plt.title("input")
plt.imshow(sample_slice-sample_slice*sample_ground_truth*0.4, cmap='gray')
plt.show()
plt.title("mask")
plt.imshow(sample_ground_truth, cmap='gray')
plt.show()

# %%
def edge(mask)->np:
    img = np.array(255*mask, dtype=np.uint8)
    return cv2.Canny(img,3, 30)

plt.imshow(edge(sample_ground_truth), cmap='gray')
